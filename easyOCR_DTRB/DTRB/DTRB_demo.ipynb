# %%
# !pip install torchvision==0.15.1
# !pip install numpy==1.23.5
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 89.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 99.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 50.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.2 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/clovaai/deep-text-recognition-benchmark.git
# %cd deep-text-recognition-benchmark
# Out:
# Cloning into 'deep-text-recognition-benchmark'...
# remote: Enumerating objects: 499, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 499 (delta 208), reused 200 (delta 200), pack-reused 274 (from 1)
# Receiving objects: 100% (499/499), 3.05 MiB | 16.55 MiB/s, done.
# Resolving deltas: 100% (308/308), done.
# /content/deep-text-recognition-benchmark

# %%
# !pip install gdown
# !gdown 1b59rXuGGmKne1AuHnkgDzoYgKeETNMv9
# !pip install lmdb
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1b59rXuGGmKne1AuHnkgDzoYgKeETNMv9
# From (redirected): https://drive.google.com/uc?id=1b59rXuGGmKne1AuHnkgDzoYgKeETNMv9&confirm=t&uuid=cbc0dce2-55e8-4a64-9d84-d0d2c1a71de8
# To: /content/deep-text-recognition-benchmark/TPS-ResNet-BiLSTM-Attn.pth
# 100% 199M/199M [00:02<00:00, 88.5MB/s]
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 10.8 MB/s eta 0:00:00
# ...

# %%
# !python3 demo.py \
--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn \
--image_folder demo_image/ \
--saved_model TPS-ResNet-BiLSTM-Attn.pth
# Out:
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TPS-ResNet-BiLSTM-Attn.pth
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# demo_image/demo_1.png    	available                	0.9999
# demo_image/demo_2.jpg    	shakeshack               	0.9530
# ...

# %%
import subprocess
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


command = [
    "python3", "demo.py",
    "--Transformation", "TPS",
    "--FeatureExtraction", "ResNet",
    "--SequenceModeling", "BiLSTM",
    "--Prediction", "Attn",
    "--image_folder", "latin_handwritting/",
    "--saved_model", "TPS-ResNet-BiLSTM-Attn.pth"
]

process = subprocess.run(command, capture_output=True, text=True)
print(process.stdout)


image_path = "latin_handwritting/Handwriting.jpg"
image = mpimg.imread(image_path)

plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TPS-ResNet-BiLSTM-Attn.pth
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# latin_handwritting/Handwriting.jpg	heavy                    	0.0498

# %%
command = [
    "python3", "demo.py",
    "--Transformation", "TPS",
    "--FeatureExtraction", "ResNet",
    "--SequenceModeling", "BiLSTM",
    "--Prediction", "Attn",
    "--image_folder", "persian_handrwriting/",
    "--saved_model", "TPS-ResNet-BiLSTM-Attn.pth"
]

process = subprocess.run(command, capture_output=True, text=True)
print(process.stdout)


image_path = "persian_handrwriting/persian_handwriting.png"
image = mpimg.imread(image_path)

plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TPS-ResNet-BiLSTM-Attn.pth
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# persian_handrwriting/persian_handwriting.png	contanting               	0.0000

# %%
command = [
    "python3", "demo.py",
    "--Transformation", "TPS",
    "--FeatureExtraction", "ResNet",
    "--SequenceModeling", "BiLSTM",
    "--Prediction", "Attn",
    "--image_folder", "latin_plate/",
    "--saved_model", "TPS-ResNet-BiLSTM-Attn.pth"
]

process = subprocess.run(command, capture_output=True, text=True)
print(process.stdout)


image_path = "latin_plate/latin_plate.jpg"
image = mpimg.imread(image_path)

plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TPS-ResNet-BiLSTM-Attn.pth
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# latin_plate/latin_plate.jpg	102586                   	0.5626

# %%
command = [
    "python3", "demo.py",
    "--Transformation", "TPS",
    "--FeatureExtraction", "ResNet",
    "--SequenceModeling", "BiLSTM",
    "--Prediction", "Attn",
    "--image_folder", "persian_plate/",
    "--saved_model", "TPS-ResNet-BiLSTM-Attn.pth"
]

process = subprocess.run(command, capture_output=True, text=True)
print(process.stdout)


image_path = "persian_plate/persian_plate.png"
image = mpimg.imread(image_path)

plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from TPS-ResNet-BiLSTM-Attn.pth
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# persian_plate/persian_plate.png	spaffy                   	0.0062
